# %% [markdown]
# # 02_entiry-extract

# %% [markdown]
# ### read stored data from DataPlatform

# %%
from dsmlibrary.datanode import DataNode
import json
from tqdm.auto import tqdm
import pandas as pd

# %%
dir_rawData_id = 87
dir_processData_id = 89

# %%
datanode = DataNode()
# Out:
# Init DataNode sucessful!

# %%
meta, fp = datanode.get_file(datanode.get_file_id(directory_id=dir_rawData_id, name='dataforthai.json'))
meta
# Out:
# {'owner': 'kanyalak',
#  'human_size': '263.83 KB',
#  'name': 'dataforthai.json',
#  'description': '-',
#  'directory': 87,
#  'path': 'kanyalak/DSI310-09/rawData/dataforthai.json'}

# %%
data = json.load(fp)
data
# Out:
# [{'name': '168 เคซีพี',
#   'reg_cap': '15,000,000',
#   'province': 'กรุงเทพมหานคร',
#   'district': 'เขตยานนาวา'},
#  {'name': '168 สตูดิโอ แอนด์ ซัพพลาย',
#   'reg_cap': '1,000,000',
#   'province': 'กรุงเทพมหานคร',
#   'district': 'เขตมีนบุรี'},
#  {'name': '2 เอ็มเอ็น',
#   'reg_cap': '4,000,000',
#   'province': 'กรุงเทพมหานคร',
#   'district': 'เขตบางบอน'},
#  {'name': '3 เจ จิวเวลรี่',
#   'reg_cap': '3,000,000',
#   'province': 'กรุงเทพมหานคร',
#   'district': 'เขตจอมทอง'},
#  {'name': '484',
#   'reg_cap': '1,000,000',
#   'province': 'กรุงเทพมหานคร',
#   'district': 'เขตมีนบุรี'},
#  {'name': '484',
#   'reg_cap': '1,000,000',
#   'province': 'กรุงเทพมหานคร',
#   'district': 'เขตธนบุรี'},
#  {'name': '99 ซิลเวอร์ 2009',
#   'reg_cap': '1,000,000',
#   'province': 'ปทุมธานี',
#   'district': 'คลองหลวง'},
#  {'name': 'กรรณิการ์มณี',
#   'reg_cap': '4,000,000',
#   'province': 'กรุงเทพมหานคร',
#   'district': 'เขตดินแดง'},
#  {'name': 'กรอซเซ่ จีเวลส์ (ประเทศไทย)',
# ...

# %%
df = pd.json_normalize(data)

# %% [markdown]
# ### write DataNode to DataPlatform

# %%
datanode.write( df=df, 
                directory=dir_processData_id, 
                name="week04_dataforthai", 
                profiling=True, 
                lineage=[datanode.get_file_id(directory_id=dir_rawData_id, name='dataforthai.json')],
                description="ข้อมูลชุดที่4: รายชื่อผู้ประกอบการหมวดธุรกิจการผลิตเครื่องประดับจากอัญมณีและโลหะมีค่า ประกอบไปด้วยชื่อผู้ประกอบการ, ทุนจดทะเบียน, จังหวัดและอำเภอ เพื่อนำมาใช้รวบรวมชื่อผู้ประกอบการอัญมณีเพื่อนำไปจัดกลุ่มต่อไปซึ่งเก็บข้อมูลเมื่อวันที่ 15/11/2022"
              )
# Out:
# File week03_thaigem.parquet alrady exists, do you want to replace y/n :  y
# {'sucess': True,
#  'file_id': 753,
#  'path': 'kanyalak/DSI310-09/processData/week03_thaigem.parquet',
#  'lineage': True}
