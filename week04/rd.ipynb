# %%
import pandas as pd

# %%
read = pd.read_html('https://www.rd.go.th/gew/reportutf8.htm')[0]
read
# Out:
#       ลำดับ  เลขประจำตัวผู้เสียภาษีอากร  เลขประจำตัวผู้เสียภาษีอากร(13 หลัก)  \
# 0         1                  3101958430                         105534038143
# 1         2                  3101577785                         105531096576
# 2         3                  3101962741                         105534040610
# 3         4                  3101074062                         105520010128
# 4         5                  3101172201                         105524015779
# ...     ...                         ...                                  ...
# 1182   1183                  3042298039                         105565126150
# 1183   1184                  3011533321                         105538013781
# 1184   1185                  3036814078                         105557186106
# 1185   1186                  3036355175                         105557032559
# 1186   1187                  3038097639                         225560000084
#
# ...
