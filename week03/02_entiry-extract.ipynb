# %% [markdown]
# # 02_entiry-extract

# %% [markdown]
# ### read stored data from DataPlatform

# %%
from dsmlibrary.datanode import DataNode
import json
from tqdm.auto import tqdm
import pandas as pd

# %%
dir_rawData_id = 87
dir_processData_id = 89

# %%
datanode = DataNode()
# Out:
# Init DataNode sucessful!

# %%
meta, fp = datanode.get_file(datanode.get_file_id(directory_id=dir_rawData_id, name='thaigem.json'))
meta
# Out:
# {'owner': 'kanyalak',
#  'human_size': '206.85 KB',
#  'name': 'thaigem.json',
#  'description': '-',
#  'directory': 87,
#  'path': 'kanyalak/DSI310-09/rawData/thaigem.json'}

# %%
data = json.load(fp)
data
# Out:
# [{'name': 'PAUL WILD (THAILAND) CO.,LTD.',
#   'product_type': 'Gemstones',
#   'bussiness_type': 'Wholesaler, Exporter'},
#  {'name': 'RESSIGEAC GEMS CO.,LTD.',
#   'product_type': 'Gemstones',
#   'bussiness_type': 'Wholesaler, Exporter'},
#  {'name': 'YU FENG JEWELRY CO.,LTD.',
#   'product_type': 'Gemstones',
#   'bussiness_type': 'Retailer, Wholesaler, Importer, Exporter'},
#  {'name': 'EMERALD MINES CO.,LTD.',
#   'product_type': 'Gemstones',
#   'bussiness_type': 'Retailer, Wholesaler, Importer, Exporter'},
#  {'name': 'LA SIAM GEMS INTER CO.,LTD.',
#   'product_type': 'Gemsotnes,Precious and Semi Precious Stones',
#   'bussiness_type': 'Exporter, Importer, Wholesaler, Retailer'},
#  {'name': 'AMERICAN GEMSTONE LTD.',
#   'product_type': 'Equipment and Tools,3D Printer & Software,3D Printer & Software',
#   'bussiness_type': '3D Service,3D Service'},
#  {'name': 'NEMI-RAJ GEMS CO.,LTD.',
# ...

# %%
df = pd.json_normalize(data)

# %% [markdown]
# ### write DataNode to DataPlatform

# %%
datanode.write( df=df, 
                directory=dir_processData_id, 
                name="week03_thaigem", 
                profiling=True, 
                lineage=[datanode.get_file_id(directory_id=dir_rawData_id, name='bkkbiz.json')],
                description="ข้อมูลชุดที่3: รายชื่อสมาชิกสมาคมผู้ค้าอัญมณีไทยและเครื่องประดับ ประกอบไปด้วยชื่อผู้ประกอบการ, ประเภทสินต้า, ประเภทธุรกิจ เพื่อนำมาใช้รวบรวมชื่อผู้ประกอบการอัญมณีเพื่อนำไปจัดกลุ่มต่อไปซึ่งเก็บข้อมูลเมื่อวันที่ 8/11/2022"
              )
# Out:
# File week03_thaigem.parquet alrady exists, do you want to replace y/n :  y
# {'sucess': True,
#  'file_id': 753,
#  'path': 'kanyalak/DSI310-09/processData/week03_thaigem.parquet',
#  'lineage': True}
