# %% [markdown]
# # 01_scrap
# - scrapping data from https://www.rd.go.th/gew/reportutf8.htm and upload to DataPlatform

# %% [markdown]
# ## Getting data from newsdata.io

# %%
import requests
import pandas as pd

# %%
vat = pd.read_html('https://www.rd.go.th/gew/reportutf8.htm')[0]
vat
# Out:
#       ลำดับ  เลขประจำตัวผู้เสียภาษีอากร  เลขประจำตัวผู้เสียภาษีอากร(13 หลัก)  \
# 0         1                  3101958430                         105534038143
# 1         2                  3101461046                         105530040704
# 2         3                  3101577785                         105531096576
# 3         4                  3101962741                         105534040610
# 4         5                  3101074062                         105520010128
# ...     ...                         ...                                  ...
# 1185   1186                  3036355175                         105557032559
# 1186   1187                  3039156175                         105561080279
# 1187   1188                  3038097639                         225560000084
# 1188   1189                  3042194447                         105565114267
# 1189   1190                  3042142837                         105565099888
#
#                         ชื่อผู้ประกอบการ  \
# ...

# %%
vat['เลขประจำตัวผู้เสียภาษีอากร'] = vat['เลขประจำตัวผู้เสียภาษีอากร'].astype('object')
vat['เลขประจำตัวผู้เสียภาษีอากร(13 หลัก)'] = vat['เลขประจำตัวผู้เสียภาษีอากร(13 หลัก)'].astype('object')

# %%
vat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 8 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ลำดับ                                1190 non-null   int64
#  1   เลขประจำตัวผู้เสียภาษีอากร           1190 non-null   object
#  2   เลขประจำตัวผู้เสียภาษีอากร(13 หลัก)  1190 non-null   object
#  3   ชื่อผู้ประกอบการ                     1190 non-null   object
#  4   ที่ตั้งสถานประกอบการ                 1190 non-null   object
#  5   สมาชิกสมาคม                          1190 non-null   object
#  6   วันเดือนปีที่มีสิทธิ                 1190 non-null   object
#  7   วันสิ้นสุดสมาชิกภาพ                  1190 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 74.5+ KB

# %%
table = vat
table
# Out:
#       ลำดับ เลขประจำตัวผู้เสียภาษีอากร เลขประจำตัวผู้เสียภาษีอากร(13 หลัก)  \
# 0         1                 3101958430                        105534038143
# 1         2                 3101461046                        105530040704
# 2         3                 3101577785                        105531096576
# 3         4                 3101962741                        105534040610
# 4         5                 3101074062                        105520010128
# ...     ...                        ...                                 ...
# 1185   1186                 3036355175                        105557032559
# 1186   1187                 3039156175                        105561080279
# 1187   1188                 3038097639                        225560000084
# 1188   1189                 3042194447                        105565114267
# 1189   1190                 3042142837                        105565099888
#
#                         ชื่อผู้ประกอบการ  \
# ...

# %% [markdown]
# - dump data to json file

# %%
import json
rd = []

# %%
table = table.to_dict('records')

# %%
with open('rd.json', 'w') as f:
    json.dump(table, f)

# %%
print (f"page:{len(table)}")
# Out:
# page:1190

# %% [markdown]
# ## Upload data to DataPlatform

# %%
from dsmlibrary.datanode import DataNode

# %%
dir_rawData_id = 87

# %%
datanode = DataNode()
# Out:
# Init DataNode sucessful!

# %%
datanode.upload_file(directory_id=dir_rawData_id, file_path='rd.json')
# Out:
# File rd.json alrady exists, do you want to replace y/n :  y
#   0%|          | 0.00/1.81M [00:00<?, ?B/s]
# {'id': 775,
#  'msg': 'file rd.json create sucessful',
#  'path': 'kanyalak/DSI310-09/rawData/rd.json',
#  'uploaded': True}
