# %% [markdown]
# # 01_scrap
# - scrapping data from newsdata.io and upload to DataPlatform

# %% [markdown]
# ## Getting data from newsdata.io

# %%
import requests
import pandas as pd

# %%
vat = pd.read_html('https://www.rd.go.th/gew/reportutf8.htm')[0]
vat
# Out:
#       ลำดับ  เลขประจำตัวผู้เสียภาษีอากร  เลขประจำตัวผู้เสียภาษีอากร(13 หลัก)  \
# 0         1                  3101958430                         105534038143
# 1         2                  3101461046                         105530040704
# 2         3                  3101577785                         105531096576
# 3         4                  3101962741                         105534040610
# 4         5                  3101074062                         105520010128
# ...     ...                         ...                                  ...
# 1232   1233                  3036355175                         105557032559
# 1233   1234                  3039156175                         105561080279
# 1234   1235                  3038097639                         225560000084
# 1235   1236                  3042194447                         105565114267
# 1236   1237                  3042142837                         105565099888
#
#                         ชื่อผู้ประกอบการ  \
# 0            บริษัท พร็อสเพอร์สโตน จำกัด
# 1               บริษัท เจย์ เย็มส์ จำกัด
# 2       บริษัท ลีฟวิง สโตน ไดมอนด์ จำกัด
# 3             บริษัท วอง จิวเวลรี่ จำกัด
# 4     บริษัท เอสโก้ เอ็นเตอร์ไพรส์ จำกัด
# ...                                  ...
# 1232         บริษัท บราเธอร์ เจมส์ จำกัด
# 1233             บริษัท นาโซ แอนนา จำกัด
# 1234              บริษัท อโน เจมส์ จำกัด
# 1235       บริษัท จี.เอส. ไดมอนด์ส จำกัด
# 1236         บริษัท ซามาร์ จีเวลส์ จำกัด
#
#                                    ที่ตั้งสถานประกอบการ  \
# 0     7 ซ. โพธิ์แก้ว 3 แยก 16 ย. - ต.คลองจั่น อ.บางกะปิ
# 1     322/67 ซ. อาคารสุรวงษวัฒนาคาร ชั้น 24 ย. - ต.ส...
# 2     410/154-156 ซ. อาคารดิเอ็กเซ็คคิวทีฟเฮ้าส์ ชั้...
# 3                      212/3 ซ. ย. - ต.สามเสนใน อ.พญาไท
# 4     36 ซ. ชาเตอร์แบงค์(เจริญกรุง 38) ย. - ต.บางรัก...
# ...                                                 ...
# 1232  919/1 ซ. อาคารจิวเวลรี่เทรดเซ็นเตอร์ ชั้น บี1 ...
# 1233  919/1 ซ. อาคารจิวเวลรี่เทรดเซ็นเตอร์ ชั้น G ห้...
# 1234        43/80 ซ. - ย. - ต.จันทนิมิต อ.เมืองจันทบุรี
# 1235  1249/162 ซ. อาคารเจมส์ทาวเวอร์ ชั้น 20 ห้อง อี...
# 1236  110 ซ. ปราโมทย์ อาคาร เอ็ม วาย เค ชั้น 2 ห้อง ...
#
#                                     สมาชิกสมาคม วันเดือนปีที่มีสิทธิ  \
# 0          สมาคมผู้ค้าอัญมณีไทยและเครื่องประดับ           25/02/2546
# 1          สมาคมผู้ค้าอัญมณีไทยและเครื่องประดับ           18/04/2546
# 2            สมาคมการค้าเพชรและพลอยอินเดียน-ไทย           18/04/2546
# 3          สมาคมผู้ค้าอัญมณีไทยและเครื่องประดับ           19/04/2546
# 4          สมาคมผู้ค้าอัญมณีไทยและเครื่องประดับ           21/04/2546
# ...                                         ...                  ...
# 1232       สมาคมผู้ค้าอัญมณีไทยและเครื่องประดับ           06/10/2565
# 1233       สมาคมผู้ค้าอัญมณีไทยและเครื่องประดับ           18/10/2565
# 1234  สมาคมผู้ค้าอัญมณีและเครื่องประดับจันทบุรี           25/10/2565
# 1235       สมาคมผู้ค้าอัญมณีไทยและเครื่องประดับ           02/11/2565
# 1236       สมาคมผู้ค้าอัญมณีไทยและเครื่องประดับ           03/11/2565
#
#      วันสิ้นสุดสมาชิกภาพ
# 0             31/12/2565
# 1             31/12/2566
# 2             31/12/2565
# 3             31/12/2565
# 4             31/12/2565
# ...                  ...
# 1232          31/12/2565
# 1233          31/12/2566
# 1234          31/12/2566
# 1235          31/12/2565
# 1236          31/12/2565
#
# [1237 rows x 8 columns]

# %%
vat['เลขประจำตัวผู้เสียภาษีอากร'] = vat['เลขประจำตัวผู้เสียภาษีอากร'].astype('object')
vat['เลขประจำตัวผู้เสียภาษีอากร(13 หลัก)'] = vat['เลขประจำตัวผู้เสียภาษีอากร(13 หลัก)'].astype('object')

# %%
vat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1237 entries, 0 to 1236
# Data columns (total 8 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ลำดับ                                1237 non-null   int64
#  1   เลขประจำตัวผู้เสียภาษีอากร           1237 non-null   object
#  2   เลขประจำตัวผู้เสียภาษีอากร(13 หลัก)  1237 non-null   object
#  3   ชื่อผู้ประกอบการ                     1237 non-null   object
#  4   ที่ตั้งสถานประกอบการ                 1237 non-null   object
#  5   สมาชิกสมาคม                          1237 non-null   object
#  6   วันเดือนปีที่มีสิทธิ                 1237 non-null   object
#  7   วันสิ้นสุดสมาชิกภาพ                  1237 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 77.4+ KB

# %%
table = vat
table
# Out:
#       ลำดับ เลขประจำตัวผู้เสียภาษีอากร เลขประจำตัวผู้เสียภาษีอากร(13 หลัก)  \
# 0         1                 3101958430                        105534038143
# 1         2                 3101461046                        105530040704
# 2         3                 3101577785                        105531096576
# 3         4                 3101962741                        105534040610
# 4         5                 3101074062                        105520010128
# ...     ...                        ...                                 ...
# 1232   1233                 3036355175                        105557032559
# 1233   1234                 3039156175                        105561080279
# 1234   1235                 3038097639                        225560000084
# 1235   1236                 3042194447                        105565114267
# 1236   1237                 3042142837                        105565099888
#
#                         ชื่อผู้ประกอบการ  \
# 0            บริษัท พร็อสเพอร์สโตน จำกัด
# 1               บริษัท เจย์ เย็มส์ จำกัด
# 2       บริษัท ลีฟวิง สโตน ไดมอนด์ จำกัด
# 3             บริษัท วอง จิวเวลรี่ จำกัด
# 4     บริษัท เอสโก้ เอ็นเตอร์ไพรส์ จำกัด
# ...                                  ...
# 1232         บริษัท บราเธอร์ เจมส์ จำกัด
# 1233             บริษัท นาโซ แอนนา จำกัด
# 1234              บริษัท อโน เจมส์ จำกัด
# 1235       บริษัท จี.เอส. ไดมอนด์ส จำกัด
# 1236         บริษัท ซามาร์ จีเวลส์ จำกัด
#
#                                    ที่ตั้งสถานประกอบการ  \
# 0     7 ซ. โพธิ์แก้ว 3 แยก 16 ย. - ต.คลองจั่น อ.บางกะปิ
# 1     322/67 ซ. อาคารสุรวงษวัฒนาคาร ชั้น 24 ย. - ต.ส...
# 2     410/154-156 ซ. อาคารดิเอ็กเซ็คคิวทีฟเฮ้าส์ ชั้...
# 3                      212/3 ซ. ย. - ต.สามเสนใน อ.พญาไท
# 4     36 ซ. ชาเตอร์แบงค์(เจริญกรุง 38) ย. - ต.บางรัก...
# ...                                                 ...
# 1232  919/1 ซ. อาคารจิวเวลรี่เทรดเซ็นเตอร์ ชั้น บี1 ...
# 1233  919/1 ซ. อาคารจิวเวลรี่เทรดเซ็นเตอร์ ชั้น G ห้...
# 1234        43/80 ซ. - ย. - ต.จันทนิมิต อ.เมืองจันทบุรี
# 1235  1249/162 ซ. อาคารเจมส์ทาวเวอร์ ชั้น 20 ห้อง อี...
# 1236  110 ซ. ปราโมทย์ อาคาร เอ็ม วาย เค ชั้น 2 ห้อง ...
#
#                                     สมาชิกสมาคม วันเดือนปีที่มีสิทธิ  \
# 0          สมาคมผู้ค้าอัญมณีไทยและเครื่องประดับ           25/02/2546
# 1          สมาคมผู้ค้าอัญมณีไทยและเครื่องประดับ           18/04/2546
# 2            สมาคมการค้าเพชรและพลอยอินเดียน-ไทย           18/04/2546
# 3          สมาคมผู้ค้าอัญมณีไทยและเครื่องประดับ           19/04/2546
# 4          สมาคมผู้ค้าอัญมณีไทยและเครื่องประดับ           21/04/2546
# ...                                         ...                  ...
# 1232       สมาคมผู้ค้าอัญมณีไทยและเครื่องประดับ           06/10/2565
# 1233       สมาคมผู้ค้าอัญมณีไทยและเครื่องประดับ           18/10/2565
# 1234  สมาคมผู้ค้าอัญมณีและเครื่องประดับจันทบุรี           25/10/2565
# 1235       สมาคมผู้ค้าอัญมณีไทยและเครื่องประดับ           02/11/2565
# 1236       สมาคมผู้ค้าอัญมณีไทยและเครื่องประดับ           03/11/2565
#
#      วันสิ้นสุดสมาชิกภาพ
# 0             31/12/2565
# 1             31/12/2566
# 2             31/12/2565
# 3             31/12/2565
# 4             31/12/2565
# ...                  ...
# 1232          31/12/2565
# 1233          31/12/2566
# 1234          31/12/2566
# 1235          31/12/2565
# 1236          31/12/2565
#
# [1237 rows x 8 columns]

# %% [markdown]
# - dump data to json file

# %%
import json
rd = []

# %%
table = table.to_dict('records')

# %%
with open('rd.json', 'w') as f:
    json.dump(table, f)

# %% [markdown]
# ## Upload data to DataPlatform

# %%
from dsmlibrary.datanode import DataNode

# %%
dir_rawData_id = 87

# %%
datanode = DataNode()
# Out:
# Init DataNode sucessful!

# %%
datanode.upload_file(directory_id=dir_rawData_id, file_path='rd.json')
# Out:
# File rd.json alrady exists, do you want to replace y/n :  y
#   0%|          | 0.00/1.89M [00:00<?, ?B/s]
# {'id': 775,
#  'msg': 'file rd.json create sucessful',
#  'path': 'kanyalak/DSI310-09/rawData/rd.json',
#  'uploaded': True}
